# %% [markdown]
# ## Lettura Dati

# %%
import os
import pandas as pd

# %%
PATH_DATA = r"C:\Users\laudi\OneDrive\Desktop\zuky\financial_analysis\data"
PATH_DATA_FAIL = os.path.join(PATH_DATA, "Societa fallite new.xlsx")
PATH_DATA_NOT_FAIL = os.path.join(PATH_DATA, "Societa non fallite new.xlsx")

# %%
df_fail = pd.read_excel(PATH_DATA_FAIL, sheet_name="Calcolo variabili adj")
df_not_fail = pd.read_excel(PATH_DATA_NOT_FAIL, sheet_name="Calcolo variabili adj")

# %% [markdown]
# ## Analisi Primo Livello: Descrittiva

# %% [markdown]
# ### ROA

# %%
roa_fail = df_fail["ROA"]
roa_not_fail = df_not_fail["ROA"]

# %%
print("Descrizione delle società fallite:\n")
print(roa_fail.describe())
print("-"*50)
print("Descrizione delle società non fallite:\n")
print(roa_not_fail.describe())
# Out:
# Descrizione delle società fallite:
#
# count    52.000000
# mean     -0.604741
# std       1.825671
# min     -13.287242
# 25%      -0.572530
# 50%      -0.303202
# 75%      -0.100494
# max       0.184677
# Name: ROA, dtype: float64
# --------------------------------------------------
# Descrizione delle società non fallite:
#
# count    52.000000
# mean      0.057591
# std       0.084337
# min      -0.129651
# 25%       0.011994
# 50%       0.044183
# 75%       0.089681
# max       0.444145
# Name: ROA, dtype: float64
